# %%
import pandas as pd
import datetime as dt
import pandas_datareader as pdr
company= "BAC"
start="2014-01-01"
end="2018-12-31"
df=pdr.DataReader(name=company,data_source='iex',start=start,end=end)

# %%
someday=df.index[500]
someday=pd.to_datetime(someday)
someday
# Out:
# Timestamp('2016-01-07 00:00:00')

# %%
someday.day
# Out:
# 7

# %%
someday.week
# Out:
# 1

# %%
someday.month
# Out:
# 1

# %%
someday.year
# Out:
# 2016

# %%
someday.day_name()
# Out:
# 'Thursday'

# %%
someday.is_month_start
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1251 entries, 2014-01-13 to 2018-12-31
# Data columns (total 5 columns):
# open      1251 non-null float64
# high      1251 non-null float64
# low       1251 non-null float64
# close     1251 non-null float64
# volume    1251 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 58.6+ KB

# %%
df.index=pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['2014-01-13', '2014-01-14', '2014-01-15', '2014-01-16',
#                '2014-01-17', '2014-01-21', '2014-01-22', '2014-01-23',
#                '2014-01-24', '2014-01-27',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='date', length=1251, freq=None)

# %%
df.index.day_name()
# Out:
# Index(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Tuesday',
#        'Wednesday', 'Thursday', 'Friday', 'Monday',
#        ...
#        'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Monday',
#        'Wednesday', 'Thursday', 'Friday', 'Monday'],
#       dtype='object', name='date', length=1251)

# %%
df.insert(0,"Dias de la Semana",df.index.day_name())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1251 entries, 2014-01-13 to 2018-12-31
# Data columns (total 6 columns):
# Dias de la Semana    1251 non-null object
# open                 1251 non-null float64
# high                 1251 non-null float64
# low                  1251 non-null float64
# close                1251 non-null float64
# volume               1251 non-null int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 68.4+ KB

# %%
df.head
# Out:
# <bound method NDFrame.head of            Dias de la Semana     open     high      low    close     volume
# date
# 2014-01-13            Monday  15.6731  15.6824  15.3090  15.3370   90827849
# 2014-01-14           Tuesday  15.4397  15.6544  15.4304  15.6544   98517898
# 2014-01-15         Wednesday  16.0838  16.2612  15.9718  16.0091  330005943
# 2014-01-16          Thursday  15.9531  15.9998  15.8598  15.9438  163879260
# 2014-01-17            Friday  16.0558  16.0745  15.8598  15.8785   96509703
# 2014-01-21           Tuesday  15.9438  16.0138  15.7478  15.8785  118388995
# 2014-01-22         Wednesday  15.9438  16.0091  15.8691  16.0091   68231534
# 2014-01-23          Thursday  15.9345  15.9531  15.6264  15.7384  124037063
# 2014-01-24            Friday  15.5611  15.6077  15.3557  15.3557  114269725
# 2014-01-27            Monday  15.2810  15.4397  14.9917  15.2250  135060624
# 2014-01-28           Tuesday  15.3557  15.6451  15.2810  15.6171   93652513
# ...

# %%
df.insert(1,"inicio de mes",df.index.is_month_start)
df.head
# Out:
# <bound method NDFrame.head of            Dias de la Semana  inicio de mes     open     high      low  \
# date
# 2014-01-13            Monday          False  15.6731  15.6824  15.3090
# 2014-01-14           Tuesday          False  15.4397  15.6544  15.4304
# 2014-01-15         Wednesday          False  16.0838  16.2612  15.9718
# 2014-01-16          Thursday          False  15.9531  15.9998  15.8598
# 2014-01-17            Friday          False  16.0558  16.0745  15.8598
# 2014-01-21           Tuesday          False  15.9438  16.0138  15.7478
# 2014-01-22         Wednesday          False  15.9438  16.0091  15.8691
# 2014-01-23          Thursday          False  15.9345  15.9531  15.6264
# 2014-01-24            Friday          False  15.5611  15.6077  15.3557
# 2014-01-27            Monday          False  15.2810  15.4397  14.9917
# 2014-01-28           Tuesday          False  15.3557  15.6451  15.2810
# 2014-01-29         Wednesday          False  15.4491  15.7291  15.3931
# ...

# %%
df[df['inicio de mes']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dias de la Semana</th>
#       <th>inicio de mes</th>
#       <th>open</th>
#       <th>high</th>
#       <th>low</th>
#       <th>close</th>
#       <th>volume</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-04-01</th>
#       <td>Tuesday</td>
#       <td>True</td>
#       <td>16.1401</td>
#       <td>16.2522</td>
#       <td>16.1215</td>
#       <td>16.1962</td>
#       <td>57423776</td>
#     </tr>
#     <tr>
# ...

# %%
mascaraa=df[df['inicio de mes']]
mascaraa.head
# Out:
# <bound method NDFrame.head of            Dias de la Semana  inicio de mes     open     high      low  \
# date
# 2014-04-01           Tuesday           True  16.1401  16.2522  16.1215
# 2014-05-01          Thursday           True  14.1413  14.2136  14.0386
# 2014-07-01           Tuesday           True  14.3747  14.6271  14.3747
# 2014-08-01            Friday           True  14.1878  14.3841  13.8700
# 2014-10-01         Wednesday           True  16.0034  16.0222  15.7503
# 2014-12-01            Monday           True  15.8628  15.8815  15.6847
# 2015-04-01         Wednesday           True  14.5441  14.5818  14.3838
# 2015-05-01            Friday           True  15.0912  15.2327  15.0157
# 2015-06-01            Monday           True  15.6382  15.6948  15.5345
# 2015-07-01         Wednesday           True  16.3190  16.3757  16.1676
# 2015-09-01           Tuesday           True  15.0891  15.1837  14.6256
# 2015-10-01          Thursday           True  14.7296  14.8435  14.5778
# ...
