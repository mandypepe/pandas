# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
df=pd.read_csv("csvs/employees.csv",parse_dates=['Last Login Time','Start Date'])
df['Senior Management']=df['Senior Management'].astype("bool")
df['Gender']=df['Gender'].astype('category')
df.sort_values('First Name',inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 101 to 951
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 56.7+ KB

# %%
df.head
# Out:
# <bound method NDFrame.head of     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2019-01-05 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2019-01-05 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2019-01-05 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2019-01-05 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2019-01-05 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2019-01-05 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2019-01-05 11:59:00   71276    5.027
# 538       Adam    Male 2010-10-08 2019-01-05 21:53:00   45181    3.491
# 300       Alan    Male 1988-06-26 2019-01-05 03:54:00  111786    3.592
# 53        Alan     NaN 2014-03-03 2019-01-05 13:28:00   40341   17.578
# 610       Alan    Male 2012-02-17 2019-01-05 00:26:00   41453   10.084
# 372     Albert    Male 1997-02-01 2019-01-05 16:20:00   67827   19.717
# ...

# %%
df[df['First Name'].duplicated(keep='first')] # retorna las duplicadas evade la 1ra
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
# 141     True
# 302     True
# 538     True
# 300    False
# 53      True
# 610     True
# 372    False
# 458     True
# 477     True
# 680     True
# 999     True
# 959     True
# 988    False
# 970     True
# 765     True
# 425     True
# 905     True
# 684     True
# 935     True
# 693     True
# 639    False
# 642     True
# 578     True
# 553     True
# 542     True
#        ...
# 567     True
# 574     True
# 599     True
# 607     True
# 608     True
# 626     True
# 628     True
# 674     True
# 685     True
# 687     True
# 697     True
# 709     True
# 733     True
# 734     True
# 773     True
# 774     True
# 782     True
# 783     True
# 785     True
# 812     True
# 821     True
# 823     True
# 826     True
# 877     True
# 890     True
# 902     True
# 925     True
# 946     True
# 947     True
# 951     True
# Name: First Name, Length: 1000, dtype: bool

# %%
df[df['First Name'].duplicated(keep='last')] # evade el ultimo y selecciona los anteriores
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>First Name</th>
#       <th>Gender</th>
#       <th>Start Date</th>
#       <th>Last Login Time</th>
#       <th>Salary</th>
#       <th>Bonus %</th>
#       <th>Senior Management</th>
#       <th>Team</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>101</th>
#       <td>Aaron</td>
#       <td>Male</td>
#       <td>2012-02-17</td>
#       <td>2019-01-05 10:20:00</td>
#       <td>61602</td>
#       <td>11.849</td>
#       <td>True</td>
#       <td>Marketing</td>
#     </tr>
#     <tr>
#       <th>327</th>
#       <td>Aaron</td>
#       <td>Male</td>
#       <td>1994-01-29</td>
# ...

# %%
df['First Name'].duplicated(keep=False) # sacara todos los duplicados
# Out:
# 101    True
# 327    True
# 440    True
# 937    True
# 137    True
# 141    True
# 302    True
# 538    True
# 300    True
# 53     True
# 610    True
# 372    True
# 458    True
# 477    True
# 680    True
# 999    True
# 959    True
# 988    True
# 970    True
# 765    True
# 425    True
# 905    True
# 684    True
# 935    True
# 693    True
# 639    True
# 642    True
# 578    True
# 553    True
# 542    True
#        ...
# 567    True
# 574    True
# 599    True
# 607    True
# 608    True
# 626    True
# 628    True
# 674    True
# 685    True
# 687    True
# 697    True
# 709    True
# 733    True
# 734    True
# 773    True
# 774    True
# 782    True
# 783    True
# 785    True
# 812    True
# 821    True
# 823    True
# 826    True
# 877    True
# 890    True
# 902    True
# 925    True
# 946    True
# 947    True
# 951    True
# Name: First Name, Length: 1000, dtype: bool

# %%
df['First Name'].count()
# Out:
# 933

# %%
df['First Name'].describe()
# Out:
# count         933
# unique        200
# top       Marilyn
# freq           11
# Name: First Name, dtype: object

# %%
df['First Name'].value_counts()
# Out:
# Marilyn     11
# Barbara     10
# Todd        10
# Jeremy      10
# Sarah        9
# Steven       9
# Irene        9
# Kathy        9
# Rose         9
# Cynthia      9
# Alice        8
# Andrea       8
# Ruby         8
# Julie        8
# Clarence     8
# Gloria       8
# Justin       8
# Harry        8
# Bobby        8
# Carl         8
# Ruth         7
# Robin        7
# Scott        7
# James        7
# Robert       7
# Thomas       7
# Marie        7
# Peter        7
# Brandon      7
# Linda        7
#             ..
# Jimmy        3
# Heather      2
# Kelly        2
# Joan         2
# Emily        2
# Chris        2
# Julia        2
# Paula        2
# Jose         2
# Anna         2
# Mildred      2
# Juan         2
# Wanda        2
# Eric         2
# Andrew       2
# Martha       2
# Dorothy      2
# Janet        2
# Martin       2
# Pamela       2
# Timothy      2
# Dennis       1
# Keith        1
# Angela       1
# Eugene       1
# Carol        1
# Brian        1
# ...

# %%
mask=~df['First Name'].duplicated(keep=False) #negando 
mask.head
# Out:
# <bound method NDFrame.head of 101    False
# 327    False
# 440    False
# 937    False
# 137    False
# 141    False
# 302    False
# 538    False
# 300    False
# 53     False
# 610    False
# 372    False
# 458    False
# 477    False
# 680    False
# 999    False
# 959    False
# 988    False
# 970    False
# 765    False
# 425    False
# 905    False
# 684    False
# 935    False
# 693    False
# 639    False
# 642    False
# 578    False
# 553    False
# 542    False
#        ...
# 567    False
# 574    False
# 599    False
# 607    False
# 608    False
# 626    False
# 628    False
# 674    False
# 685    False
# 687    False
# 697    False
# 709    False
# 733    False
# 734    False
# 773    False
# 774    False
# 782    False
# 783    False
# 785    False
# 812    False
# 821    False
# 823    False
# 826    False
# 877    False
# 890    False
# 902    False
# 925    False
# 946    False
# 947    False
# 951    False
# Name: First Name, Length: 1000, dtype: bool>
