# %%
import pandas as pd
import datetime as dt
import pandas_datareader as pdr
from matplotlib import *
import matplotlib as plt
import pandas_datareader as data
# %matplotlib inline
start="2014-01-01"
end="2014-12-31"

#$companie=['MSFT','BAC','AAPL','FB','AMZN']
companie='FB'
p=data.DataReader(name=companie,data_source='iex',start=start,end=end)
p.index=pd.to_datetime(p.index)

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 95 entries, 2014-01-14 to 2014-05-30
# Data columns (total 5 columns):
# open      95 non-null float64
# high      95 non-null float64
# low       95 non-null float64
# close     95 non-null float64
# volume    95 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 4.5 KB

# %%
p.plot()

# %%
p['open'].plot(x='date',y='open')

# %%
p['high'].plot()

# %%
p[['high','low']].plot()

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('fivethirtyeight')
p.plot(y='close')

# %%
plt.style.use('ggplot')
p.plot(y='low')

# %%
p.head(3
    )
# Out:
#              open   high    low  close    volume
# date
# 2014-01-14  56.46  57.78  56.10  57.74  37590987
# 2014-01-15  57.98  58.57  57.27  57.60  33730619
# 2014-01-16  57.26  58.02  56.83  57.19  34599775

# %%
plt.style.use('ggplot')
p['low'].apply(lambda x: "bajo" if x<=57 else("Satisfactorio" if(x >58 and x <=60)else "grande")).value_counts().plot(kind='bar')

# %%
p['low'].apply(lambda x: "bajo" if x<=57 else("Satisfactorio" if(x >58 and x <=60)else "grande")).value_counts().plot(kind='barh')

# %%
p['close'].sum()
# Out:
# 5925.3629

# %%
p['close'].mean()
# Out:
# 62.372241052631544

# %%
p['low'].apply(lambda x: "UPPER" if x>=62.372241052631544 else "DOWN").value_counts().plot(kind='pie',legend=True)

# %%
p['volume']
# Out:
# date
# 2014-01-14     37590987
# 2014-01-15     33730619
# 2014-01-16     34599775
# 2014-01-17     40883205
# 2014-01-21     48734147
# 2014-01-22     61495880
# 2014-01-23     47996403
# 2014-01-24     55545338
# 2014-01-27     74142331
# 2014-01-28     48364998
# 2014-01-29     98089932
# 2014-01-30    150438699
# 2014-01-31     87930298
# 2014-02-03     75105994
# 2014-02-04     46064897
# 2014-02-05     53032420
# 2014-02-06     42153754
# 2014-02-07     60835746
# 2014-02-10     43736562
# 2014-02-11     45746832
# 2014-02-12     47409857
# 2014-02-13     62013396
# 2014-02-14     36786427
# 2014-02-18     43862297
# 2014-02-19     64258631
# 2014-02-20    131043748
# 2014-02-21     70991892
# 2014-02-24     76951946
# 2014-02-25     52189031
# 2014-02-26     55400399
#                 ...
# 2014-04-17     88040346
# 2014-04-21     60363619
# 2014-04-22     60631312
# 2014-04-23     96564750
# 2014-04-24    138769345
# 2014-04-25     92501529
# 2014-04-28    107757756
# ...

# %%
p.head(25)
# Out:
#              open     high      low   close     volume
# date
# 2014-01-14  56.46  57.7800  56.1000  57.740   37590987
# 2014-01-15  57.98  58.5700  57.2700  57.600   33730619
# 2014-01-16  57.26  58.0200  56.8300  57.190   34599775
# 2014-01-17  57.30  57.8200  56.0700  56.300   40883205
# 2014-01-21  56.60  58.5800  56.5000  58.510   48734147
# 2014-01-22  58.85  59.3100  57.1000  57.510   61495880
# 2014-01-23  56.37  56.6800  55.6855  56.630   47996403
# 2014-01-24  56.15  56.4200  54.4000  54.450   55545338
# 2014-01-27  54.73  54.9401  51.8500  53.550   74142331
# 2014-01-28  54.02  55.2800  54.0000  55.140   48364998
# 2014-01-29  54.61  54.9500  53.1900  53.530   98089932
# 2014-01-30  62.12  62.5000  60.4600  61.080  150438699
# 2014-01-31  60.47  63.3700  60.1700  62.570   87930298
# 2014-02-03  63.03  63.7700  60.7000  61.480   75105994
# 2014-02-04  62.05  63.1400  61.8200  62.750   46064897
# 2014-02-05  62.74  63.1600  61.2700  62.190   53032420
# ...

# %%
p['high'].apply(lambda x: int(x / 10.0) * 10).value_counts()
# Out:
# 70    114
# 60     95
# 50     24
# 80     11
# Name: high, dtype: int64

# %%
p['high'].apply(lambda x: int(x / 1.0) * 1).value_counts()
# Out:
# 75    23
# 77    18
# 74    18
# 78    17
# 63    16
# 67    12
# 76    11
# 64    11
# 68    10
# 65    10
# 60    10
# 73    10
# 61     9
# 71     9
# 58     9
# 69     8
# 59     7
# 80     6
# 62     5
# 66     4
# 81     4
# 79     4
# 57     3
# 56     2
# 54     2
# 70     2
# 72     2
# 55     1
# 82     1
# Name: high, dtype: int64

# %%
p['high'].apply(lambda x: int(x / 1.0) * 1).nunique()
# Out:
# 29

# %%
p['high'].apply(lambda x: int(x / 1.0) * 1).plot(kind='hist',bins=29)
