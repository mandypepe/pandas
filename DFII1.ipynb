# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
df=pd.read_csv("csvs/employees.csv",parse_dates=['Last Login Time','Start Date'])
df['Senior Management']=df['Senior Management'].astype("bool")
df['Gender']=df['Gender'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
df[df['Gender']=="Male"] # modifica el DF extrae solo los hombres
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>First Name</th>
#       <th>Gender</th>
#       <th>Start Date</th>
#       <th>Last Login Time</th>
#       <th>Salary</th>
#       <th>Bonus %</th>
#       <th>Senior Management</th>
#       <th>Team</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Douglas</td>
#       <td>Male</td>
#       <td>1993-08-06</td>
#       <td>2019-01-05 12:42:00</td>
#       <td>97308</td>
#       <td>6.945</td>
#       <td>True</td>
#       <td>Marketing</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Thomas</td>
#       <td>Male</td>
#       <td>1996-03-31</td>
# ...

# %%
df[df['Team']=="Finance"] # modifica el df y solo deja finance team sea true
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>First Name</th>
#       <th>Gender</th>
#       <th>Start Date</th>
#       <th>Last Login Time</th>
#       <th>Salary</th>
#       <th>Bonus %</th>
#       <th>Senior Management</th>
#       <th>Team</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>Maria</td>
#       <td>Female</td>
#       <td>1993-04-23</td>
#       <td>2019-01-05 11:17:00</td>
#       <td>130590</td>
#       <td>11.858</td>
#       <td>False</td>
#       <td>Finance</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Jerry</td>
#       <td>Male</td>
#       <td>2005-03-04</td>
# ...

# %%
df[df['Senior Management']] # es bool column .. por tanto lo asume
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>First Name</th>
#       <th>Gender</th>
#       <th>Start Date</th>
#       <th>Last Login Time</th>
#       <th>Salary</th>
#       <th>Bonus %</th>
#       <th>Senior Management</th>
#       <th>Team</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Douglas</td>
#       <td>Male</td>
#       <td>1993-08-06</td>
#       <td>2019-01-05 12:42:00</td>
#       <td>97308</td>
#       <td>6.945</td>
#       <td>True</td>
#       <td>Marketing</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Thomas</td>
#       <td>Male</td>
#       <td>1996-03-31</td>
# ...

# %%
df[df['Team']!="Marketing"]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>First Name</th>
#       <th>Gender</th>
#       <th>Start Date</th>
#       <th>Last Login Time</th>
#       <th>Salary</th>
#       <th>Bonus %</th>
#       <th>Senior Management</th>
#       <th>Team</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Thomas</td>
#       <td>Male</td>
#       <td>1996-03-31</td>
#       <td>2019-01-05 06:53:00</td>
#       <td>61933</td>
#       <td>4.170</td>
#       <td>True</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Maria</td>
#       <td>Female</td>
#       <td>1993-04-23</td>
# ...

# %%
df[df['Salary'] > 110000]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>First Name</th>
#       <th>Gender</th>
#       <th>Start Date</th>
#       <th>Last Login Time</th>
#       <th>Salary</th>
#       <th>Bonus %</th>
#       <th>Senior Management</th>
#       <th>Team</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>Maria</td>
#       <td>Female</td>
#       <td>1993-04-23</td>
#       <td>2019-01-05 11:17:00</td>
#       <td>130590</td>
#       <td>11.858</td>
#       <td>False</td>
#       <td>Finance</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Jerry</td>
#       <td>Male</td>
#       <td>2005-03-04</td>
# ...

# %%
df[df['Bonus %']< 1.5]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>First Name</th>
#       <th>Gender</th>
#       <th>Start Date</th>
#       <th>Last Login Time</th>
#       <th>Salary</th>
#       <th>Bonus %</th>
#       <th>Senior Management</th>
#       <th>Team</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>Larry</td>
#       <td>Male</td>
#       <td>1998-01-24</td>
#       <td>2019-01-05 16:47:00</td>
#       <td>101004</td>
#       <td>1.389</td>
#       <td>True</td>
#       <td>Client Services</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Lillian</td>
#       <td>Female</td>
#       <td>2016-06-05</td>
# ...

# %%
df[df['Start Date']<= '1985-01-01']
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>First Name</th>
#       <th>Gender</th>
#       <th>Start Date</th>
#       <th>Last Login Time</th>
#       <th>Salary</th>
#       <th>Bonus %</th>
#       <th>Senior Management</th>
#       <th>Team</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td>Louise</td>
#       <td>Female</td>
#       <td>1980-08-12</td>
#       <td>2019-01-05 09:01:00</td>
#       <td>63241</td>
#       <td>15.132</td>
#       <td>True</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Brandon</td>
#       <td>Male</td>
#       <td>1980-12-01</td>
# ...
