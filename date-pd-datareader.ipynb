# %%
import pandas as pd
import datetime as dt
import pandas_datareader as pdr

# %%
company= "BAC"
start="2014-01-01"
end="2018-12-31"
df=pdr.DataReader(name=company,data_source='iex',start=start,end=end)

# %%
df.head
# Out:
# <bound method NDFrame.head of                open     high      low    close     volume
# date
# 2014-01-13  15.6731  15.6824  15.3090  15.3370   90827849
# 2014-01-14  15.4397  15.6544  15.4304  15.6544   98517898
# 2014-01-15  16.0838  16.2612  15.9718  16.0091  330005943
# 2014-01-16  15.9531  15.9998  15.8598  15.9438  163879260
# 2014-01-17  16.0558  16.0745  15.8598  15.8785   96509703
# 2014-01-21  15.9438  16.0138  15.7478  15.8785  118388995
# 2014-01-22  15.9438  16.0091  15.8691  16.0091   68231534
# 2014-01-23  15.9345  15.9531  15.6264  15.7384  124037063
# 2014-01-24  15.5611  15.6077  15.3557  15.3557  114269725
# 2014-01-27  15.2810  15.4397  14.9917  15.2250  135060624
# 2014-01-28  15.3557  15.6451  15.2810  15.6171   93652513
# 2014-01-29  15.4491  15.7291  15.3931  15.5704  130381992
# 2014-01-30  15.6918  15.8598  15.6498  15.8038   91147776
# 2014-01-31  15.6077  15.8505  15.5051  15.6358  139608553
# 2014-02-03  15.6544  15.7571  15.2157  15.2624  160718806
# ...

# %%
df.values
# Out:
# array([[1.56731000e+01, 1.56824000e+01, 1.53090000e+01, 1.53370000e+01,
#         9.08278490e+07],
#        [1.54397000e+01, 1.56544000e+01, 1.54304000e+01, 1.56544000e+01,
#         9.85178980e+07],
#        [1.60838000e+01, 1.62612000e+01, 1.59718000e+01, 1.60091000e+01,
#         3.30005943e+08],
#        ...,
#        [2.37800000e+01, 2.43700000e+01, 2.33900000e+01, 2.43700000e+01,
#         9.15754020e+07],
#        [2.45900000e+01, 2.47500000e+01, 2.42600000e+01, 2.43900000e+01,
#         7.86937970e+07],
#        [2.45700000e+01, 2.49700000e+01, 2.43700000e+01, 2.46400000e+01,
#         5.62573420e+07]])

# %%
df.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')

# %%
df.index
# Out:
# Index(['2014-01-13', '2014-01-14', '2014-01-15', '2014-01-16', '2014-01-17',
#        '2014-01-21', '2014-01-22', '2014-01-23', '2014-01-24', '2014-01-27',
#        ...
#        '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20', '2018-12-21',
#        '2018-12-24', '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-31'],
#       dtype='object', name='date', length=1251)

# %%
df.axes
# Out:
# [Index(['2014-01-13', '2014-01-14', '2014-01-15', '2014-01-16', '2014-01-17',
#         '2014-01-21', '2014-01-22', '2014-01-23', '2014-01-24', '2014-01-27',
#         ...
#         '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20', '2018-12-21',
#         '2018-12-24', '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-31'],
#        dtype='object', name='date', length=1251),
#  Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1251 entries, 2014-01-13 to 2018-12-31
# Data columns (total 5 columns):
# open      1251 non-null float64
# high      1251 non-null float64
# low       1251 non-null float64
# close     1251 non-null float64
# volume    1251 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 58.6+ KB

# %%
df['low'].describe()
# Out:
# count    1251.000000
# mean       19.667529
# std         6.091836
# min        10.459700
# 25%        14.781850
# 50%        16.170100
# 75%        24.351850
# max        32.171000
# Name: low, dtype: float64

# %%
df.loc['2014-03-04']
# Out:
# open      1.538370e+01
# high      1.562640e+01
# low       1.533700e+01
# close     1.561710e+01
# volume    1.017019e+08
# Name: 2014-03-04, dtype: float64

# %%
df.iloc[300]
# Out:
# open      1.483650e+01
# high      1.490250e+01
# low       1.472330e+01
# close     1.472330e+01
# volume    7.701098e+07
# Name: 2015-03-24, dtype: float64

# %%
df.loc['2014-10-01':'2015-10-07'].head
# Out:
# <bound method NDFrame.head of                open     high      low    close     volume
# date
# 2014-10-01  16.0034  16.0222  15.7503  15.7690   91235935
# 2014-10-02  15.8065  15.9284  15.5909  15.8253  118018774
# 2014-10-03  16.0409  16.2191  15.9940  16.2097  110840569
# 2014-10-06  16.2847  16.3222  16.1441  16.2097   66212066
# 2014-10-07  16.1065  16.1253  15.8253  15.8253   91396327
# 2014-10-08  15.8253  16.0503  15.6753  16.0503  101266804
# 2014-10-09  15.9753  16.0409  15.5159  15.5534  121363088
# 2014-10-10  15.4878  15.7222  15.3378  15.4503  129552650
# 2014-10-13  15.4503  15.6284  15.3753  15.3753   92674130
# 2014-10-14  15.4784  15.5909  15.3378  15.4878   97451881
# 2014-10-15  15.2159  15.2253  14.4659  14.7753  216591804
# 2014-10-16  14.6346  15.2347  14.5503  15.0753  148199432
# 2014-10-17  15.2347  15.3847  15.1503  15.1972   94339180
# 2014-10-20  15.1878  15.3097  15.1503  15.2440   76510730
# 2014-10-21  15.4034  15.5722  15.2909  15.5628   78287334
# ...

# %%
cumples=pd.date_range(start='1984-09-05',end='2018-12-31', freq=pd.DateOffset(years=1))

# %%
len(pd.date_range(start='1984-09-05',end='2018-12-31', freq=pd.DateOffset(years=1)))
# Out:
# 35

# %%
df.index.isin(cumples)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
mascara=df.index.isin(cumples)

# %%
esta=df.loc[mascara]
esta.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: [open, high, low, close, volume]
# Index: []>
